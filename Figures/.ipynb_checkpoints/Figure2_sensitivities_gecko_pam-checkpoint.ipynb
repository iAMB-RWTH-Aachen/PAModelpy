# %% [markdown]
# # Code to generate figure 2 in the publication
# Analysis of sensitive enzymes and reactions in the model simulations

# %%
from matplotlib import pyplot as plt
import matplotlib
import matplotlib.gridspec as gridspec

import pandas as pd
import numpy as np
import os
import sys

import numpy as np
from PIL import Image

from PAModelpy.configuration import Config
from PAModelpy.EnzymeSectors import ActiveEnzymeSector, UnusedEnzymeSector, TransEnzymeSector, CustomSector

sys.path.append('../Scripts/')
from pam_generation import set_up_ecoli_pam

BIOMASS_RXNID = Config.BIOMASS_REACTION
DATA_DIR = os.path.join(os.path.split(os.getcwd())[0], 'Data')
PAM_DATA_FILE_PATH = os.path.join(DATA_DIR, 'proteinAllocationModel_iML1515_EnzymaticData_py.xls')
glc_uptake_rates = list(np.linspace(0.5, 10, 20))
# Out:
# Loading PAModelpy modules version 0.0.2.8

# %% [markdown]
# ## sensitivities of GECKO and PAM

# %% [markdown]
# ### 1 Usefull functions

# %%
def calculate_sensitivities(pamodel):
    glc_uptake_rates = np.linspace(0.5, 10, 20)
    Ccsc = []
    Cvsc = []
    y_axis = []
    fluxes = []
    
    # disable pyruvate formate lyase (inhibited by oxygen)
    pamodel.change_reaction_bounds(rxn_id = 'PFL', upper_bound = 0)
    
    for glc in glc_uptake_rates:
        print('glucose uptake rate ', glc, ' mmol/gcdw/h')
        with pamodel:
            # change glucose uptake rate
            pamodel.change_reaction_bounds(rxn_id = 'EX_glc__D_e', 
                                            lower_bound = -glc, upper_bound = -glc)
            # solve the model
            sol_pam = pamodel.optimize()
            fluxes.append(sol_pam.fluxes)
            if pamodel.solver.status == 'optimal': y_axis += [glc]
            # save data
            Ccsc_new = list()
            
            if pamodel.solver.status == 'optimal':
                capacity_coeff = pamodel.capacity_sensitivity_coefficients
                for csc in ['flux_ub', 'flux_lb', 'enzyme_max','enzyme_min','proteome', 'sector']:
                    Ccsc_new += capacity_coeff[capacity_coeff['constraint'] == csc].coefficient.to_list()
                
                Ccsc += [Ccsc_new]
    
                variable_coeff = pamodel.variable_sensitivity_coefficients
                Cvsc_new = list()
                for vsc in ['flux', 'enzyme', 'sector']:
                    Cvsc_new += variable_coeff[variable_coeff['constraint'] == vsc].coefficient.to_list()
                Cvsc += [Cvsc_new]
                
                print('Sum of capacity sensitivity coefficients: \t \t \t \t \t \t', round(sum(Ccsc_new),6))
                print('Sum of variable sensitivity coefficients: \t \t \t \t \t \t', round(sum(Cvsc_new),6),'\n')

    return {'Ccsc':Ccsc, 'Cvsc':Cvsc, 'y_axis':y_axis, 'fluxes':fluxes, 'capacity coefficients':capacity_coeff, 'variable coefficients':variable_coeff}

# %%
def parse_x_axis_heatmap(capacity_coeff, variable_coeff):
    x_axis_vsc = []
    x_axis_csc = []
    
    for csc in ['flux_ub', 'flux_lb', 'enzyme_max','enzyme_min','proteome', 'sector']:
        if csc == 'flux_ub' or csc == 'flux_lb':
            x_axis_csc += [coef+'_'+ csc for coef in capacity_coeff[capacity_coeff['constraint'] == csc].rxn_id.to_list()]
        else:
            x_axis_csc += [coef+'_'+ csc for coef in capacity_coeff[
            capacity_coeff['constraint'] == csc].enzyme_id.to_list()]
    
    for vsc in ['flux', 'enzyme', 'sector']:
        if vsc == 'flux':
            x_axis_vsc += variable_coeff[variable_coeff['constraint'] == vsc].rxn_id.to_list()
        else:
            x_axis_vsc += variable_coeff[
                variable_coeff['constraint'] == vsc].enzyme_id.to_list()
    return x_axis_csc, x_axis_vsc

# %%
def make_heatmap_subfigure(results, csc_matrix, vsc_matrix, x_csc, x_vsc, yaxis, fig, grdspc, ylabels = True, cbar =True, 
                           fontsize = 16, vmin = -1.5, vmax = 1.5, annotate = None, phenotype_data = None, cmap = plt.cm.get_cmap('viridis')
):
    # fig = plt.figure()

    if cbar:
        gs = gridspec.GridSpecFromSubplotSpec(3, 2, width_ratios=[len(yaxis), 1], 
                                            height_ratios=[1,len(x_csc), len(x_vsc)], hspace =0,
                                              subplot_spec=grdspc)
    else:
        gs = gridspec.GridSpecFromSubplotSpec(3, 1, width_ratios=[len(yaxis)], 
                                            height_ratios=[1,len(x_csc), len(x_vsc)], hspace =0,
                                              subplot_spec=grdspc)

    # gs = gridspec.GridSpec(3, 2, width_ratios=[len(yaxis), 1], height_ratios=[1,len(x_csc), len(x_vsc)], hspace =0)
    
    vsc_ax = fig.add_subplot(gs[2,0]) #VSC heatmap
    acetate_ax = fig.add_subplot(gs[0,0]) #acetate production
    csc_ax = fig.add_subplot(gs[1,0],sharex = vsc_ax) #CAC heatmap
    if cbar:
        cbar_ax = fig.add_subplot(gs[1:,1]) #colorbar

    #add annotation for subfigure (A or B)
    if annotate is not None:
        acetate_ax.annotate(annotate, xy=(2, 1), xycoords='data',
            xytext=(-0.05,1.5), textcoords='axes fraction',
            va='top', ha='left', fontsize = fontsize+5, weight = 'bold')

    glc_fluxes = [-sim.EX_glc__D_e for sim in results['fluxes']]
    
    #add arrow indicating growth regime
    #1. Find the start of the overflow regime (which is when acetate is being produced)
    for i,ac in enumerate([sim.EX_ac_e for sim in results['fluxes']]):
        if ac >0.01:
            glc_onset = glc_fluxes[i]
            break
    #2. determine the dx covered by respiration
    dx_respiration =  glc_onset-glc_fluxes[0]
    #3 create respiration arrow
    #forward arrow
    acetate_ax.arrow(
            glc_fluxes[0], 11, dx_respiration, 0,
        linewidth = 2, color = 'purple', label = 'Respiration', length_includes_head = True, head_width = 3, head_length = 0.5
    )
    #reverse arrow
    acetate_ax.arrow(
            glc_onset, 11, -dx_respiration, 0, head_starts_at_zero = True,
        linewidth = 2, color = 'purple', label = 'Respiration', length_includes_head = True, head_width = 3, head_length = 0.5
    )
    #annotate
    acetate_ax.annotate('Respiration',
                       xy=(dx_respiration/2, 15),
                         xytext=(10, -10), fontsize = fontsize,
                         textcoords='offset points', color = 'purple')
    #4. create overflow arrow
    #forward arrow
    acetate_ax.arrow(
        glc_onset, 11, 10-glc_onset,0,
        linewidth = 2, color = 'darkgreen', label = 'Overflow', length_includes_head = True,head_width = 3, head_length = 0.5
    )
    #reverse arrow
    acetate_ax.arrow(
        10, 11, -(10-glc_onset),0,
        linewidth = 2, color = 'darkgreen', label = 'Overflow', length_includes_head = True,head_width = 3, head_length = 0.5
    )
    #annotate
    acetate_ax.annotate('Overflow',fontsize = fontsize,
                       xy=((10-glc_onset)/2+glc_onset, 15),
                         xytext=(10, -10),
                         textcoords='offset points', color = 'darkgreen')
    
    #acetate graph
    acetate_ax.plot([-sim.EX_glc__D_e for sim in results['fluxes']], [sim.EX_ac_e for sim in results['fluxes']], 
                    linewidth = 4)
    acetate_ax.tick_params(axis='y', labelsize=fontsize)
    acetate_ax.set_xlim([0, 10.5])
    acetate_ax.set_ylim([-0.5, 15])
    acetate_ax.xaxis.set_visible(False)
    if ylabels:
        acetate_ax.set_ylabel(r'Acetate' '\n' '[$mmol_{ac}/g_{CDW}/h$]',fontsize =fontsize, rotation = 0)

    #add phenotype data if this is given
    if phenotype_data is not None:
        acetate_ax.scatter(phenotype_data['EX_glc__D_e'], phenotype_data['EX_ac_e'],
                   color='purple', marker='o', s=40, linewidths=1.3,
                   facecolors=None, zorder=0,
                   label='Data')
    
    #CAC heatmap
    im_csc = csc_ax.imshow(csc_matrix, aspect="auto", vmin = vmin, vmax =vmax, cmap = cmap)
    csc_ax.set_yticks(np.arange(len(x_csc)), labels=x_csc, fontsize =fontsize)
    csc_ax.xaxis.set_visible(False)
    if ylabels:
        csc_ax.set_ylabel('CSC', fontsize = fontsize)

    #Make line between CSC and VSC data more clear
    axis = 'bottom'
    csc_ax.spines[axis].set_linewidth(10)
    csc_ax.spines[axis].set_color("black")
    csc_ax.spines[axis].set_zorder(0)
    
    #FVSC heatmap
    im_vsc = vsc_ax.imshow(vsc_matrix, aspect="auto", vmin = vmin, vmax =vmax, cmap = cmap)
    vsc_ax.set_yticks(np.arange(len(x_vsc)), labels=x_vsc, fontsize =fontsize)
    vsc_ax.set_xticks(np.arange(len(yaxis)),labels = yaxis, fontsize =fontsize, rotation=45, ha='right')
    # vsc_ax.set_xlabel('Glucose uptake rate [$mmol_{glc}/g_{CDW}/h$]', fontsize = fontsize)
    if ylabels:
        vsc_ax.set_ylabel('VSC', fontsize = fontsize)
        
    #colorbar
    if cbar:
        cbar_ax.xaxis.set_visible(False)
        # cbar_ax.yaxis.set_visible(False)
        make_scaled_colorbar(ax=cbar_ax, vmin=vmin, vmax=vmax, fig = fig, fontsize = fontsize*1.25, cmap = cmap)
    # fig.set_figwidth(24)
    # fig.set_figheight(7)
    # fig.align_labels()
    return fig

# %%
def make_scaled_colorbar(ax, fig, cmap="viridis", vmin =-1, vmax = 1, fontsize = 16, cbarlabel = 'Sensitivity Coefficient'):
    norm = matplotlib.colors.Normalize(vmin=vmin, vmax=vmax)
    sm = matplotlib.cm.ScalarMappable(cmap=cmap, norm = norm)
    sm.set_array([])
    
    cbar = fig.colorbar(sm, ax =ax, cax=ax, shrink = 1, fraction = 1)
    #setting the fontsize of the colourbar
    cbar.set_label(cbarlabel,fontsize=fontsize)
    cbar.ax.tick_params(labelsize=fontsize)
    cbar.ax.yaxis.get_offset_text().set(size=fontsize)

# %%
#adjust labels for better readibility
def adjust_heatmap_labels(labels):
    new_labels = labels.copy()

    for i, label in enumerate(labels):
        if label =='EX_glc__D_e' or label[:-3] == 'EX_glc__D_e':
            if label[-1] == 'B': new_labels[i] = 'EX_glc_'+label[-2:]
            else: new_labels[i] = 'EX_glc'
        if label == 'TotalProteinConstraint_proteome':
            new_labels[i] = 'Protein pool'
        if label[0].isdigit(): #all enzyme ids start with a digit
            rxn_ids = pamodel.get_reactions_with_enzyme_id(label)
            rxn_name = pamodel.reactions.get_by_id(rxn_ids[-1]).name.split('(')[0]
            new_labels[i] = '\n'.join([part for part in rxn_name.split(' ')])
            
            # if len(rxn_ids)>2:
            #     new_labels[i] = pamodel.reactions.get_by_id(rxn_ids[-1]).name.split('(')[0]
            # else:
                
            #     new_labels[i] = ',\n'.join([pamodel.reactions.get_by_id(rxn_ids[-1]).name.split('(')[0]for rxn in rxn_ids])
    return new_labels

# %%
def find_nonzero_sensitivities(Cv, x_axis):
    indices = []
    for row in Cv:
        for index, coeff in enumerate(row):
            if abs(coeff)>0 and index not in indices:
                indices.append(index)
    
    coeff_nonzero = []
    for row in Cv:
        coeff_nonzero.append([coeff for i, coeff in enumerate(row) if i in indices])
    x_coeff_nonzero = [coeff for i, coeff in enumerate(x_axis) if i in indices]

    return coeff_nonzero, x_coeff_nonzero

# %%
def find_top5_sensitivities(Cv, x_axis, yaxis):
    #top 5 enzymes per simulation
    Cv_df = pd.DataFrame(Cv, columns = x_axis, index =yaxis)
    largest = list()
    for i, row in Cv_df.iterrows():
        top5 = abs(row).nlargest()        
        if top5.iloc[0]:
            largest += [index for index, value in top5.items() if abs(value)>0.05]
    
    #remove duplicates
    largest_list = list(set(largest))

    #extract non duplicate top5 enzymes
    top5_df = Cv_df[largest_list].T.drop_duplicates().sort_index()
    largest_list = top5_df.index.values

    top5_matrix = [list(row) for i, row in top5_df.iterrows()]
    return top5_matrix, largest_list

# %% [markdown]
# ### 2 Run GECKO simulations
# #### 2.1 Adjust the total protein constraint for the lack of translational and unused protein

# %%
#calculate average protein which is allocated to sectors (5 mmol_glc/gdw/h and growth rate of 0.35)
translational_info = pd.read_excel(PAM_DATA_FILE_PATH , sheet_name='Translational')
unused_protein_info = pd.read_excel(PAM_DATA_FILE_PATH, sheet_name = 'ExcessEnzymes')

#protein allocated to unused enzymes
ups_0 = unused_protein_info[unused_protein_info.Parameter == 'ups_0'].loc[2, 'Value']
smax = unused_protein_info[unused_protein_info.Parameter == 's_max_uptake'].loc[1, 'Value']
ups_mu = ups_0 / smax

ups = ups_0 - (5*ups_mu)

#protein allocated to translational enzymes
tps_0=translational_info[translational_info.Parameter == 'tps_0'].loc[1,'Value']
tps_mu=translational_info[translational_info.Parameter == 'tps_mu'].loc[2,'Value']

tps = tps_0 + (0.35*tps_mu)

#total protein left for the active enzyme sector
total_protein = 0.258 - tps - ups

print(total_protein,' g_p/g_cdw/h')
# Out:
# 0.11123186965376783  g_p/g_cdw/h

# %% [markdown]
# #### 2.2 Build GECKO model

# %%
# build the GECKO model with PAModelpy
pamodel_gecko = set_up_ecoli_pam(unused_enzymes = False, translational_enzymes = False, total_protein =total_protein)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-03-07
# Read LP format model from file /tmp/tmpn7yjyd_9.lp
# Reading time = 0.01 seconds
# : 1877 rows, 5424 columns, 21150 nonzeros
# Setting up the proteome allocation model iML1515
#
# Add total condition-dependent protein constraint
# 	Total protein concentration: 0.11123186965376783 g/gDW
#
# Add active protein sector
# /home/samiralvdb/.local/lib/python3.10/site-packages/PAModelpy/PAModel.py:220: UserWarning: Molar mass for E332 is invalid: 0.0
#   warnings.warn(f'Molar mass for {enz.id} is invalid: {molmass}')
# Done with setting up the proteome allocation model iML1515

# %% [markdown]
# #### 2.3 Run simulations for glucose uptake of 0-10 mmol/gcdw/h

# %%
results_gecko = calculate_sensitivities(pamodel_gecko)
x_axis_csc_gecko,x_axis_vsc_gecko = parse_x_axis_heatmap(results_gecko['capacity coefficients'], results_gecko['variable coefficients'])
# Out:
# glucose uptake rate  0.5  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  0.9999999999971503
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  0.0
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.0
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.0
#
# glucose uptake rate  1.0  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  0.999999999999162
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  0.0
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.0
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.0
#
# glucose uptake rate  1.5  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  0.8373967174816703
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  0.16265998514875793
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.000057
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.000057
#
# glucose uptake rate  2.0  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  0.31313647245886256
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  0.686985853825171
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.000122
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.000122
#
# glucose uptake rate  2.5  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  0.3364200673906599
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  0.6636791482079589
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.000099
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.000099
#
# glucose uptake rate  3.0  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  0.34866012893308906
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  0.6514238248737779
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.000084
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.000084
#
# glucose uptake rate  3.5  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -0.962291593635185
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  1.9627875036522682
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.000496
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.000496
#
# glucose uptake rate  4.0  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -0.6106583501814653
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  1.610895826469642
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.000237
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.000237
#
# glucose uptake rate  4.5  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -9.691524201965256
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  10.69317804484401
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.001654
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.001654
#
# glucose uptake rate  5.0  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -9.693883812948403
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  10.69550442627019
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.001621
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.001621
#
# glucose uptake rate  5.5  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -9.58221100800535
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  10.583782443161109
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.001571
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.001571
#
# glucose uptake rate  6.0  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -9.477116106689477
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  10.478641260438517
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.001525
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.001525
#
# glucose uptake rate  6.5  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -9.918583506217942
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  10.920143469609295
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.00156
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.00156
#
# glucose uptake rate  7.0  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -10.189237758635947
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  11.19086503281894
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.001627
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.001627
#
# glucose uptake rate  7.5  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -9.848682988699048
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  10.850276624780715
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.001594
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.001594
#
# glucose uptake rate  8.0  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -9.521922584622562
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  10.523483945133458
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.001561
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.001561
#
# glucose uptake rate  8.5  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -12.476610560577972
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  13.478628084788713
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.002018
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.002018
#
# glucose uptake rate  9.0  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -13.1622566384858
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  14.164379399931214
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.002123
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.002123
#
# glucose uptake rate  9.5  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -13.077552266727478
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  14.079669050839351
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.002117
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.002117
#
# glucose uptake rate  10.0  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -13.025842390332599
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  14.027954411105405
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.002112
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.002112

# %%
csc_nonzero_gecko, x_csc_nonzero_gecko = find_nonzero_sensitivities(results_gecko['Ccsc'], x_axis = x_axis_csc_gecko)
vsc_nonzero_gecko, x_vsc_nonzero_gecko = find_nonzero_sensitivities(results_gecko['Cvsc'], x_axis = x_axis_vsc_gecko)

# %%
for i in ['1.8.1.4']:
    for index, name in enumerate(x_vsc_nonzero_gecko):
        if i == name:
            for row in vsc_nonzero_gecko:
                print(i, row[index])
# Out:
# 1.8.1.4 0.0
# 1.8.1.4 0.0
# 1.8.1.4 0.009479086108613035
# 1.8.1.4 0.02299110495703729
# 1.8.1.4 0.011057371952055185
# 1.8.1.4 0.002944647865003826
# 1.8.1.4 8.378135649062501e-05
# 1.8.1.4 0.0002168968305993312
# 1.8.1.4 0.0018623543828442753
# 1.8.1.4 0.0018858196530727534
# 1.8.1.4 0.001885819653072725
# 1.8.1.4 0.0018858196530727317
# 1.8.1.4 0.0019855379331739993
# 1.8.1.4 0.0021241883311987867
# 1.8.1.4 0.0021241883311987615
# 1.8.1.4 0.0021241883311987767
# 1.8.1.4 0.002791371102256873
# 1.8.1.4 0.002950214067488622
# 1.8.1.4 0.0029502140674889372
# 1.8.1.4 0.0029518368990532886

# %%
csc_nonzero_gecko_t = np.transpose(np.array(csc_nonzero_gecko))
vsc_nonzero_gecko_t = np.transpose(np.array(vsc_nonzero_gecko))

# %%
csc_top5_gecko, x_csc_top5_gecko = find_top5_sensitivities(results_gecko['Ccsc'], x_axis = x_axis_csc_gecko, yaxis = glc_uptake_rates)
vsc_top5_gecko, x_vsc_top5_gecko = find_top5_sensitivities(results_gecko['Cvsc'], x_axis = x_axis_vsc_gecko, yaxis = glc_uptake_rates)
csc_top5_gecko_t = np.transpose(np.array(csc_top5_gecko))
vsc_top5_gecko_t = np.transpose(np.array(vsc_top5_gecko))

# %% [markdown]
# ### 3 Run PAM simulations
# #### 3.1 Build PAModel

# %%
pamodel = set_up_ecoli_pam()
# Out:
# Read LP format model from file /tmp/tmp9yb98bvm.lp
# Reading time = 0.01 seconds
# : 1877 rows, 5424 columns, 21150 nonzeros
# Setting up the proteome allocation model iML1515
#
# Add total condition-dependent protein constraint
# 	Total protein concentration: 0.258 g/gDW
#
# Add active protein sector
# /home/samiralvdb/.local/lib/python3.10/site-packages/PAModelpy/PAModel.py:220: UserWarning: Molar mass for E332 is invalid: 0.0
#   warnings.warn(f'Molar mass for {enz.id} is invalid: {molmass}')
# Add the following protein sector: TranslationalProteinSector
#
# Add the following protein sector: UnusedEnzymeSector
#
# Done with setting up the proteome allocation model iML1515

# %% [markdown]
# #### 3.2 Run simulations for glucose uptake of 0-10 mmol/gcdw/h

# %%
results_pam = calculate_sensitivities(pamodel)
x_axis_csc_pam,x_axis_vsc_pam = parse_x_axis_heatmap(results_pam['capacity coefficients'], results_pam['variable coefficients'])
# Out:
# glucose uptake rate  0.5  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -0.4367354949575444
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  1.4367354949544566
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.0
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.0
#
# glucose uptake rate  1.0  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  0.18471962010162657
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  0.8152803798974506
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.0
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.0
#
# glucose uptake rate  1.5  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  0.2918178276063814
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  0.7081821723930786
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.0
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.0
#
# glucose uptake rate  2.0  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  0.326534901215361
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  0.6734650987842518
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.0
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.0
#
# glucose uptake rate  2.5  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -0.8666208676100644
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  1.8666208676097664
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.0
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.0
#
# glucose uptake rate  3.0  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -0.7488597003880033
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  1.7490359715376727
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.000176
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.000176
#
# glucose uptake rate  3.5  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -0.6390889632895427
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  1.6393862830483399
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.000297
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.000297
#
# glucose uptake rate  4.0  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -0.609549898111577
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  1.6098310581472561
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.000281
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.000281
#
# glucose uptake rate  4.5  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -9.516079696896085
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  10.51929358944633
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.003214
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.003214
#
# glucose uptake rate  5.0  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -9.662518327157892
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  10.665523538988642
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.003005
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.003005
#
# glucose uptake rate  5.5  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -9.591289803462967
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  10.594059257050532
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.002769
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.002769
#
# glucose uptake rate  6.0  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -9.53042404846314
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  10.532992043383237
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.002568
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.002568
#
# glucose uptake rate  6.5  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -9.477812952533867
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  10.480206810761155
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.002394
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.002394
#
# glucose uptake rate  7.0  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -9.563858509367389
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  10.566128688499157
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.00227
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.00227
#
# glucose uptake rate  7.5  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -9.525184100709334
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  10.527319100937092
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.002135
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.002135
#
# glucose uptake rate  8.0  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -9.49085662427345
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  10.492871639456752
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.002015
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.002015
#
# glucose uptake rate  8.5  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -9.460182195009917
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  10.462089993667531
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.001908
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.001908
#
# glucose uptake rate  9.0  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -9.4326071499645
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  10.4344185653936
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.001811
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.001811
#
# glucose uptake rate  9.5  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -9.407684331132977
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  10.40940863367654
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.001724
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.001724
#
# glucose uptake rate  10.0  mmol/gcdw/h
# Variable Sensitivity Relationships
# ----------------------------------
# sum(EnzymeVSC)+sum(FluxCSC)+ (1-alpha)ProteomeCSC =  -9.385048650868075
# variable sensitivity relation is NOT within bounds. Please check the accuray of the solver and the model structure
#
# -sum(EnzymeVSC) + sum(EnzymeCSC) + alpha*ProteomeCSC =  10.386693834775933
# Protein space is NOT fully utilized and variable sensitivity relation is within bounds
#
# Sum of capacity sensitivity coefficients: 	 	 	 	 	 	 1.001645
# Sum of variable sensitivity coefficients: 	 	 	 	 	 	 1.001645

# %%
csc_nonzero_pam, x_csc_nonzero_pam = find_nonzero_sensitivities(results_pam['Ccsc'], x_axis = x_axis_csc_pam)
vsc_nonzero_pam, x_vsc_nonzero_pam = find_nonzero_sensitivities(results_pam['Cvsc'], x_axis = x_axis_vsc_pam)
csc_nonzero_pam_t = np.transpose(np.array(csc_nonzero_pam))
vsc_nonzero_pam_t = np.transpose(np.array(vsc_nonzero_pam))

# %%
for i in ['1.2.4.1', '2.3.1.16']:
    for index, name in enumerate(x_vsc_nonzero_pam):
        if i == name:
            for row in vsc_nonzero_pam:
                print(i, row[index])
# Out:
# 1.2.4.1 0.003605624314585503
# 1.2.4.1 0.00190459663235658
# 1.2.4.1 0.0016059496102427623
# 1.2.4.1 0.0015037767250089212
# 1.2.4.1 0.0046396697544361
# 1.2.4.1 0.004895594562930427
# 1.2.4.1 0.005031623568045733
# 1.2.4.1 0.005326741854714564
# 1.2.4.1 0.027045248639319067
# 1.2.4.1 0.028571310167261423
# 1.2.4.1 0.029359817338990717
# 1.2.4.1 0.030033607582567682
# 1.2.4.1 0.030616017890974952
# 1.2.4.1 0.0314249770147584
# 1.2.4.1 0.031486555461279236
# 1.2.4.1 0.03154121260395443
# 1.2.4.1 0.031590053265453735
# 1.2.4.1 0.03163395900300889
# 1.2.4.1 0.03167364179376939
# 1.2.4.1 0.03170968294022826
# 2.3.1.16 0.001495570599369949
# 2.3.1.16 0.0014946416033975937
# 2.3.1.16 0.001493948202422382
# 2.3.1.16 0.001515864059587012
# 2.3.1.16 0.004797644939153861
# 2.3.1.16 0.005277041657980678
# 2.3.1.16 0.0056418606898301065
# 2.3.1.16 0.006140444813760966
# 2.3.1.16 0.04119462529050822
# 2.3.1.16 0.042113152428476824
# 2.3.1.16 0.042113152428478545
# 2.3.1.16 0.042113152428478566
# 2.3.1.16 0.04211315242847855
# 2.3.1.16 0.0426437692170795
# 2.3.1.16 0.042643769217079505
# 2.3.1.16 0.042643769217079505
# 2.3.1.16 0.04264376921707951
# 2.3.1.16 0.042643769217079505
# 2.3.1.16 0.042643769217079505
# 2.3.1.16 0.042643769217079505

# %%
csc_top5_pam, x_csc_top5_pam = find_top5_sensitivities(results_pam['Ccsc'], x_axis = x_axis_csc_pam, yaxis = glc_uptake_rates)
vsc_top5_pam, x_vsc_top5_pam = find_top5_sensitivities(results_pam['Cvsc'], x_axis = x_axis_vsc_pam, yaxis = glc_uptake_rates)
csc_top5_pam_t = np.transpose(np.array(csc_top5_pam))
vsc_top5_pam_t = np.transpose(np.array(vsc_top5_pam))

# %% [markdown]
# ### 4 Create plot

# %% [markdown]
# #### 4.1 Load phenotypic data

# %%
# load phenotype data from excel file
pt_data = pd.read_excel(os.path.join(DATA_DIR, 'Ecoli_phenotypes','Ecoli_phenotypes_py_rev.xls'), sheet_name='Yields', index_col=None)
pt_data['EX_glc__D_e'] = -pt_data['EX_glc__D_e']

# %% [markdown]
# ### 4.2 Load manually created plot with mapped sensitivities

# %%
image_path = 'Figure2_mapped_sensitivities.png'

sensitivities_mapped =np.asarray(Image.open(image_path))

# %%
#create 1 big plot
fontsize = 28
width = 50
height = 35
# select colormap
cmap = plt.cm.get_cmap('magma')

# gridspec inside gridspec
fig = plt.figure(layout = 'constrained')


gs0 = gridspec.GridSpec(2, 14, figure=fig, wspace = 10000)
gs_gecko = gs0[0,:6]
gs_pam = gs0[0,7:]
gs_figure = gs0[1,:]

#adjust labels for better readibility
x_csc_label_gecko = adjust_heatmap_labels(x_csc_nonzero_gecko)
x_vsc_label_gecko = adjust_heatmap_labels(x_vsc_top5_gecko)

fig_gecko = make_heatmap_subfigure(results = results_gecko, csc_matrix=csc_nonzero_gecko_t, vsc_matrix =vsc_top5_gecko,cbar =False,
                                   x_csc=x_csc_label_gecko, x_vsc=x_vsc_label_gecko, yaxis = glc_uptake_rates, fig = fig, grdspc = gs_gecko,
                                   annotate = 'A',phenotype_data = pt_data, fontsize = fontsize, cmap=cmap)
# fig_gecko.subplots_adjust(left=0.3)
#adjust labels for better readibility
x_csc_label_pam = adjust_heatmap_labels(x_csc_nonzero_pam)
x_vsc_label_pam = adjust_heatmap_labels(x_vsc_top5_pam)

fig_pam = make_heatmap_subfigure(results = results_pam, csc_matrix=csc_nonzero_pam_t, vsc_matrix =vsc_top5_pam, ylabels = False,
                                   x_csc=x_csc_label_pam, x_vsc=x_vsc_label_pam, yaxis = glc_uptake_rates, fig = fig, grdspc=gs_pam, 
                                 annotate = 'B', phenotype_data = pt_data, fontsize = fontsize, cmap = cmap)

#set common x axis title
ax_xlabel = fig.add_subplot(gs0[0, :2])
ax_xlabel.set_xticks([])
ax_xlabel.set_yticks([])
ax_xlabel.set_frame_on(False)
ax_xlabel.set_xlabel('Glucose uptake rate [$mmol_{glc}/g_{CDW}/h$]', fontsize = fontsize*1.25)
ax_xlabel.xaxis.set_label_coords(6, -.1)

#add image

ax_fig = fig.add_subplot(gs_figure)
ax_fig.imshow(sensitivities_mapped)
ax_fig.annotate('C', xy=(2, 1), xycoords='data',
            xytext=(-0.05,1), textcoords='axes fraction',
            va='top', ha='left', fontsize = fontsize*1.5, weight = 'bold')
ax_fig.axis('off')
ax_fig.set_xticks([])
ax_fig.set_yticks([])

plt.plasma()
fig.subplots_adjust(left=0.3)
fig.set_figwidth(width)
fig.set_figheight(height)
fig.align_labels()

fig.savefig('Figure2_sensitivities_gecko_pam_magma.png', dpi =200,bbox_inches='tight')
# Out:
# /tmp/ipykernel_32054/3584346019.py:53: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   fig.subplots_adjust(left=0.3)
